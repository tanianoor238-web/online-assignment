# %% [markdown]
# #### Question 1
#
# ##### Calculate and write the output of the following expression:
# **30 + 4 × 3 − 6**

# %%
BODMAS=30 + 4 * 3 - 6
print(BODMAS)
# Out:
# 36

# %% [markdown]
# #### Question 2
#
# ##### Calculate and write the output of the following expression:
# **100 ÷ 4 + 7 − 5**

# %%
BODMAS=100 / 4 + 7 - 5
print(BODMAS)
# Out:
# 27.0

# %% [markdown]
# #### Question 3
#
# ##### Create a variable containing the string value "100". Convert it into an integer and display its data type before and after conversion.

# %%
x="100"
print(type(x))            #  data type before conversion
x=int(x)                  # convert string to integer
print(x)
print(type(x))            # data type after conversion.
# Out:
# <class 'str'>
# 100
# <class 'int'>

# %% [markdown]
# #### Question 4
#
# ##### Create the following list and display:
# ##### cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]
# ##### Second city
# ##### Fourth city

# %%
cities =["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]
cities
# Out:
# ['Karachi', 'Lahore', 'Islamabad', 'Peshawar', 'Quetta']

# %%
print("Second city:",cities[1])
# Out:
# Second city: Lahore

# %%
print("Fourth city:",cities[3])
# Out:
# Fourth city: Peshawar

# %% [markdown]
# #### Question 5
# ##### Create the following nested list and display:
# ##### students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# ##### Ali
# ##### Ayesha

# %%
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
students
# Out:
# [['Ali', 20], ['Ayesha', 22], ['Ahmed', 21]]

# %%
students[0]
# Out:
# ['Ali', 20]

# %%
students[0][0]
# Out:
# 'Ali'

# %%
students[1]
# Out:
# ['Ayesha', 22]

# %%
students[1][0]
# Out:
# 'Ayesha'

# %% [markdown]
# #### Question 6
# ##### Given list:
# ##### numbers = [10, 20, 30, 40, 50, 60, 70]
# ##### Display:
# ##### First 3 elements
# ##### Last 3 elements

# %%
numbers = [10, 20, 30, 40, 50, 60, 70]
numbers
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
print("First 3 elements :",numbers[0:3])
# Out:
# First 3 elements : [10, 20, 30]

# %%
print("last 3 elements :",numbers[-3:])
# Out:
# last 3 elements : [50, 60, 70]

# %% [markdown]
# #### Question 7
# ##### Given nested list::
# ##### students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# ##### Display:
# ##### Name of first student
# ##### Age of second student

# %%
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
students
# Out:
# [['Ali', 20], ['Ayesha', 22], ['Ahmed', 21]]

# %%
print("Name of first student:",students[0][0])
# Out:
# Name of first student: Ali

# %%
print("Age of second student:",students[1][1])
# Out:
# Age of second student: 22

# %% [markdown]
# #### Question 8
# ##### Create a list of 5 fruits and display:
# ##### First fruit
# ##### Last fruit

# %%
name_of_five_fruits=["apple","mango","orange","grapes","pear"]
name_of_five_fruits
# Out:
# ['apple', 'mango', 'orange', 'grapes', 'pear']

# %%
print("First fruit:",name_of_five_fruits[0])
# Out:
# First fruit: apple

# %%
print("last fruit:",name_of_five_fruits[4])
# Out:
# last fruit: pear

# %% [markdown]
# #### Question 9
# ##### Create the following list and display:
# ##### colors = ["Red", "Blue", "Green", "Yellow", "Black"]
# ##### First color
# ##### Last color
# ##### using negative indexing

# %%
colors = ["Red", "Blue", "Green", "Yellow", "Black"]
colors
# Out:
# ['Red', 'Blue', 'Green', 'Yellow', 'Black']

# %%
print("First color:",colors[-5])
# Out:
# First color: Red

# %%
print("last color:",colors[-1])
# Out:
# last color: Black

# %% [markdown]
# #### Question 10
# ##### Given nested list:
# ##### marks = [["Math", 90], ["Physics", 85], ["English", 88]]
# ##### Display:
# ##### Subject of second student
# ##### Marks of third student

# %%
marks = [["Math", 90], ["Physics", 85], ["English", 88]]
marks
# Out:
# [['Math', 90], ['Physics', 85], ['English', 88]]

# %%
print("Subject of second student:", marks[1][0])
# Out:
# Subject of second student: Physics

# %%
print("Marks of third student:", marks[2][1])
# Out:
# Marks of third student: 88
