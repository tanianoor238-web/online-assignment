# %% [markdown]
# #### Question 1
# #### Employee Data Bank.
#
#
#
# Make a class called Employee. The __init__() method for Employee should store its different attributes: name, number, address, salary, post, year of joining, education, and his year of experience.
#
# Make a method called describe_employee() that prints the detail Information about employee, a method update_ year_of_experience(), and a method called increase_salary() that do increamnet in it's salary.
#
# Make an instance called employee101 from your class. Print the four attri-
# butes individually, and then call all it's methods for describing employee, ssalary increamnet and increase year of experience.
#
# Create 10 different instances from the class, and call describe_employee() for each
# instance. Then do some updations with it's methods.

# %%
class Employee:
    def __init__(self,name,number,address,salary,post,year_of_joining,education,year_of_experience):
        self.name=name
        self.number=number
        self.address=address
        self.salary=salary
        self.post=post
        self.year_of_joining=year_of_joining
        self.education=education
        self.year_of_experience=year_of_experience
    def describe_employee(self):
        print(f"Name:{self.name}, Number:{self.number}, Address:{self.address}, Salary:{ self.salary}, Post{self.post}, year_of_joining{self.year_of_joining}, Education{self.education}, year_of_experience:{self.year_of_experience}")
    def update_year_of_experience(self,years):
        self.year_of_experience+=years
        print(f"Updated Experience:{self.year_of_experience} years")
    def increase_salary(self,update_salary):
        self.salary+=update_salary 
        print(f"Updated Salary:{self.salary}")

# %%
employee101=Employee("sara","03152145637","8th floor D-456 Gulshan-e-Iqbal",50000,"Accountant",2020,"M.B.A",5)

# %%
employee101.name
# Out:
# 'sara'

# %%
employee101.number
# Out:
# '03152145637'

# %%
employee101.year_of_experience
# Out:
# 5

# %%
employee101.salary
# Out:
# 50000

# %%
employee101.update_year_of_experience(7)
# Out:
# Updated Experience:12 years

# %%
employee101.increase_salary(30000)
# Out:
# Updated Salary:80000

# %%
employee1 = Employee("Ali", "03001111111", "Karachi", 40000, "Teacher", 2020, "BS", 5)

employee2 = Employee("Sara", "03002222222", "Lahore", 50000, "Manager", 2019, "MBA", 6)

employee3 = Employee("Ahmed", "03003333333", "Islamabad", 45000, "Accountant", 2021, "B.Com", 4)

employee4 = Employee("Fatima", "03004444444", "Multan", 55000, "HR", 2018, "BBA", 7)

employee5 = Employee("Noor", "03005555555", "Hyderabad", 60000, "Principal", 2015, "M.Ed", 10)

employee6 = Employee("Usman", "03006666666", "Peshawar", 47000, "Clerk", 2022, "BA", 3)

employee7 = Employee("Ayesha", "03007777777", "Quetta", 52000, "Coordinator", 2017, "MA", 8)

employee8 = Employee("Hamza", "03008888888", "Sukkur", 49000, "Supervisor", 2019, "MS", 6)

employee9 = Employee("Zain", "03009999999", "Faisalabad", 65000, "Engineer", 2016, "BE", 9)

employee10 = Employee("Mariam", "03110000000", "Rawalpindi", 43000, "Receptionist", 2023, "B.Com", 2)

# %%
employee1.describe_employee()
employee2.describe_employee()
employee3.describe_employee()
employee4.describe_employee()
employee5.describe_employee()
employee6.describe_employee()
employee7.describe_employee()
employee8.describe_employee()
employee9.describe_employee()
employee10.describe_employee()
# Out:
# Name:Ali, Number:03001111111, Address:Karachi, Salary:40000, PostTeacher, year_of_joining2020, EducationBS, year_of_experience:5
# Name:Sara, Number:03002222222, Address:Lahore, Salary:50000, PostManager, year_of_joining2019, EducationMBA, year_of_experience:6
# Name:Ahmed, Number:03003333333, Address:Islamabad, Salary:45000, PostAccountant, year_of_joining2021, EducationB.Com, year_of_experience:4
# Name:Fatima, Number:03004444444, Address:Multan, Salary:55000, PostHR, year_of_joining2018, EducationBBA, year_of_experience:7
# Name:Noor, Number:03005555555, Address:Hyderabad, Salary:60000, PostPrincipal, year_of_joining2015, EducationM.Ed, year_of_experience:10
# Name:Usman, Number:03006666666, Address:Peshawar, Salary:47000, PostClerk, year_of_joining2022, EducationBA, year_of_experience:3
# Name:Ayesha, Number:03007777777, Address:Quetta, Salary:52000, PostCoordinator, year_of_joining2017, EducationMA, year_of_experience:8
# ...

# %%
employee1.update_year_of_experience(2)
employee1.increase_salary(20000)
# Out:
# Updated Experience:7 years
# Updated Salary:60000

# %%
employee2.update_year_of_experience(3)
employee2.increase_salary(10000)
# Out:
# Updated Experience:9 years
# Updated Salary:60000

# %%
employee3.update_year_of_experience(4)
employee3.increase_salary(40000)
# Out:
# Updated Experience:8 years
# Updated Salary:85000

# %%
employee4.update_year_of_experience(5)
employee4.increase_salary(50000)
# Out:
# Updated Experience:12 years
# Updated Salary:105000

# %% [markdown]
# #### Question 2
#
# Complete the same task (Question 1) without using the Classes or OOP.

# %%
employee101={
    "name":"Nida",
    "number":"03102143368",
    "address":"8th floor D-456 Gulshan-e-Iqbal",
    "salary":50000,
    "post":"Teacher",
    "year_of_joining":2010,
    "education":"M.A",
    "year_of_experience":10
}

# %%
print(employee101["name"])
print(employee101["number"])
print(employee101["salary"])
print(employee101["post"])
# Out:
# Nida
# 03102143368
# 50000
# Teacher

# %%
def  describe_employee(employee101):
    print("Name: ",employee101["name"])
    print("Number: ",employee101["number"])
    print("Address: ",employee101["address"])
    print("Salary: ",employee101["salary"])
    print("Post: ",employee101["post"])
    print("Year_of_joining: ",employee101["year_of_joining"])
    print("Education: ",employee101["education"])
    print("Year_of_experience: ",employee101["year_of_experience"])

# %%
describe_employee(employee101)
# Out:
# Name:  Nida
# Number:  03102143368
# Address:  8th floor D-456 Gulshan-e-Iqbal
# Salary:  50000
# Post:  Teacher
# Year_of_joining:  2010
# Education:  M.A
# Year_of_experience:  10

# %%
def update_years_of_experience(employee,years):
    employee["year_of_experience"]+=years
    print("Updated EXperience: ", employee["year_of_experience"])

# %%
update_years_of_experience(employee101,2)
# Out:
# Updated EXperience:  12

# %%
def increase_salary(employee,salary):
    employee["salary"]+=salary
    print("Updated Salary: ", employee["salary"])

# %%
increase_salary(employee101,20000)
# Out:
# Updated Salary:  70000

# %%
describe_employee(employee101)
# Out:
# Name:  Nida
# Number:  03102143368
# Address:  8th floor D-456 Gulshan-e-Iqbal
# Salary:  70000
# Post:  Teacher
# Year_of_joining:  2010
# Education:  M.A
# Year_of_experience:  12

# %%
employee1 = {
    "name":"Ali",
    "number":"03001111111",
    "address":"Karachi",
    "salary":40000,
    "post":"Teacher",
    "year_of_joining":2020,
    "education":"BS",
    "year_of_experience":5
}

employee2 = {
    "name":"Sara",
    "number":"03002222222",
    "address":"Lahore",
    "salary":50000,
    "post":"Manager",
    "year_of_joining":2019,
    "education":"MBA",
    "year_of_experience":6
}

employee3 = {
    "name":"Ahmed",
    "number":"03003333333",
    "address":"Islamabad",
    "salary":45000,
    "post":"Accountant",
    "year_of_joining":2021,
    "education":"B.Com",
    "year_of_experience":4
}

employee4 = {
    "name":"Fatima",
    "number":"03004444444",
    "address":"Multan",
    "salary":55000,
    "post":"HR",
    "year_of_joining":2018,
    "education":"BBA",
    "year_of_experience":7
}

employee5 = {
    "name":"Noor",
    "number":"03005555555",
    "address":"Hyderabad",
    "salary":60000,
    "post":"Principal",
    "year_of_joining":2015,
    "education":"M.Ed",
    "year_of_experience":10
}

employee6 = {
    "name":"Usman",
    "number":"03006666666",
    "address":"Peshawar",
    "salary":47000,
    "post":"Clerk",
    "year_of_joining":2022,
    "education":"BA",
    "year_of_experience":3
}

employee7 = {
    "name":"Ayesha",
    "number":"03007777777",
    "address":"Quetta",
    "salary":52000,
    "post":"Coordinator",
    "year_of_joining":2017,
    "education":"MA",
    "year_of_experience":8
}

employee8 = {
    "name":"Hamza",
    "number":"03008888888",
    "address":"Sukkur",
    "salary":49000,
    "post":"Supervisor",
    "year_of_joining":2019,
    "education":"MS",
    "year_of_experience":6
}

employee9 = {
    "name":"Zain",
    "number":"03009999999",
    "address":"Faisalabad",
    "salary":65000,
    "post":"Engineer",
    "year_of_joining":2016,
    "education":"BE",
    "year_of_experience":9
}

employee10 = {
    "name":"Mariam",
    "number":"03110000000",
    "address":"Rawalpindi",
    "salary":43000,
    "post":"Receptionist",
    "year_of_joining":2023,
    "education":"B.Com",
    "year_of_experience":2
}

# %%
describe_employee(employee1)
describe_employee(employee2)
describe_employee(employee3)
describe_employee(employee4)
describe_employee(employee5)
describe_employee(employee6)
describe_employee(employee7)
describe_employee(employee8)
describe_employee(employee9)
describe_employee(employee10)
# Out:
# Name:  Ali
# Number:  03001111111
# Address:  Karachi
# Salary:  40000
# Post:  Teacher
# Year_of_joining:  2020
# Education:  BS
# Year_of_experience:  5
# Name:  Sara
# Number:  03002222222
# Address:  Lahore
# Salary:  50000
# Post:  Manager
# Year_of_joining:  2019
# Education:  MBA
# Year_of_experience:  6
# Name:  Ahmed
# Number:  03003333333
# Address:  Islamabad
# Salary:  45000
# Post:  Accountant
# Year_of_joining:  2021
# Education:  B.Com
# Year_of_experience:  4
# Name:  Fatima
# Number:  03004444444
# Address:  Multan
# Salary:  55000
# Post:  HR
# Year_of_joining:  2018
# Education:  BBA
# Year_of_experience:  7
# Name:  Noor
# Number:  03005555555
# Address:  Hyderabad
# Salary:  60000
# Post:  Principal
# Year_of_joining:  2015
# Education:  M.Ed
# Year_of_experience:  10
# Name:  Usman
# Number:  03006666666
# Address:  Peshawar
# Salary:  47000
# Post:  Clerk
# Year_of_joining:  2022
# Education:  BA
# Year_of_experience:  3
# Name:  Ayesha
# Number:  03007777777
# ...

# %%
def update_years_of_experience(employee1,years):
    employee1["year_of_experience"]+=years
    print("Updated EXperience: ", employee1["year_of_experience"])

# %%
update_years_of_experience(employee1,4)
# Out:
# Updated EXperience:  9

# %%
def increase_salary(employee2,salary):
    employee2["salary"]+=salary
    print("Updated Salary: ", employee2["salary"])

# %%
increase_salary(employee2,5000)
# Out:
# Updated Salary:  55000

# %%
def update_years_of_experience(employee2,years):
    employee2["year_of_experience"]+=years
    print("Updated EXperience: ", employee2["year_of_experience"])

# %%
update_years_of_experience(employee2,7)
# Out:
# Updated EXperience:  13

# %%
def increase_salary(employee3,salary):
    employee3["salary"]+=salary
    print("Updated Salary: ", employee3["salary"])

# %%
increase_salary(employee3,20000)
# Out:
# Updated Salary:  65000

# %%
def update_years_of_experience(employee3,years):
    employee3["year_of_experience"]+=years
    print("Updated EXperience: ", employee3["year_of_experience"])

# %%
update_years_of_experience(employee3,5)
# Out:
# Updated EXperience:  9
